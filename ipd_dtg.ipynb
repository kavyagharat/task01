# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyagharat/task01/blob/main/ipd_dtg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Aug 19 09:01:12 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/rafapablos/DropsToGrid.git
# Out:
# Cloning into 'DropsToGrid'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 65 (delta 2), reused 64 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (65/65), 1.01 MiB | 4.98 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# !ls DropsToGrid
# Out:
# configs  LICENSE  notebooks	  README.md  uv.lock
# dtg	 main.py  pyproject.toml  resources

# %%
# !python --version
# Out:
# Python 3.12.13

# %%
# !uv --version
# Out:
# uv 0.12.3 (x86_64-unknown-linux-gnu)

# %%
# %cd DropsToGrid
# Out:
# /content/DropsToGrid

# %%
# !uv sync
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 107 packages in 1.44s
# Prepared 102 packages in 1m 00s
# Installed 102 packages in 673ms
#  + aiohappyeyeballs==2.7.1
#  + aiohttp==3.14.1
#  + aiosignal==1.4.0
#  + asttokens==3.0.1
#  + attrs==26.1.0
#  + certifi==2026.6.17
#  + charset-normalizer==3.4.7
#  + check-shapes==1.1.1
#  + clearml==2.1.10
#  + comm==0.2.3
#  + contourpy==1.3.3
#  + cycler==0.12.1
#  + debugpy==1.8.21
#  + decorator==4.4.2
#  + docstring-parser==0.18.0
#  + dropstackframe==0.1.1
#  + einops==0.8.2
#  + executing==2.2.1
#  + filelock==3.29.4
#  + fonttools==4.63.0
#  + frozenlist==1.8.0
#  + fsspec==2025.12.0
#  + furl==2.1.4
#  + idna==3.18
#  + imageio==2.37.3
#  + imageio-ffmpeg==0.6.0
#  + importlib-resources==7.1.0
#  + ipykernel==7.3.0
#  + ipython==9.10.1
#  + ipython-pygments-lexers==1.1.1
#  + jedi==0.20.0
#  + jinja2==3.1.6
#  + jsonargparse==4.49.0
#  + jsonschema==4.26.0
# ...

# %%
# !uv run python -c "import torch; print('PyTorch:', torch.__version__); print('GPU available:', torch.cuda.is_available()); print('GPU:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None')"
# Out:
# PyTorch: 2.6.0+cu124
# GPU available: True
# GPU: Tesla T4

# %%
# !grep -n -i -E "checkpoint|pretrained|download|weights" README.md
# Out:
# 7:Example output of the pretrained `dtg_cvpr_dk` model on real (private) data, comparing radar, weather stations, and DropsToGrid's densified estimate:
# 11:This repository contains the minimum code needed to train and evaluate the model, scoped to the Denmark region, along with a pretrained checkpoint. The model was trained and evaluated on private data (radar, private weather stations, satellite, climate grids) that cannot be redistributed. Instead, training and evaluation run against `FakeDtGDataset`, a synthetic generator to run the full pipeline end-to-end and sanity-check the model.
# 22:## Pretrained checkpoint
# 24:Download the `dtg_cvpr_dk` checkpoint from Google Drive: https://drive.google.com/drive/folders/1myWuzzJMj83izt1rSJa72NOcPXwCamSP?usp=sharing.
# 26:Place it as `runs/dtg_cvpr_dk/checkpoints/`.
# 39:python main.py test --config runs/<run_name>/config.yaml <run_name> --ckpt_path runs/<run_name>/checkpoints/best.ckpt
# 48:Then load a checkpoint with:
# ...

# %%
# !mkdir -p /content/DropsToGrid/runs/dtg_cvpr_dk/checkpoints

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-06be61f2-14e4-4af0-aed9-72867643dc80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06be61f2-14e4-4af0-aed9-72867643dc80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mv /content/config.yaml /content/DropsToGrid/runs/dtg_cvpr_dk/config.yaml
# Out:
# mv: cannot stat '/content/config.yaml': No such file or directory

# %%
# !pwd
# !ls -la
# Out:
# /content/DropsToGrid
# total 476
# drwxr-xr-x  8 root root   4096 Aug 19 09:18 .
# drwxr-xr-x  1 root root   4096 Aug 19 09:16 ..
# drwxr-xr-x  2 root root   4096 Aug 19 09:16 configs
# -rw-r--r--  1 root root   1336 Aug 19 09:18 config.yaml
# drwxr-xr-x 10 root root   4096 Aug 19 09:16 dtg
# drwxr-xr-x  8 root root   4096 Aug 19 09:16 .git
# -rw-r--r--  1 root root     53 Aug 19 09:16 .gitignore
# -rw-r--r--  1 root root   1334 Aug 19 09:16 LICENSE
# -rw-r--r--  1 root root     62 Aug 19 09:16 main.py
# drwxr-xr-x  2 root root   4096 Aug 19 09:16 notebooks
# -rw-r--r--  1 root root    606 Aug 19 09:16 pyproject.toml
# -rw-r--r--  1 root root      5 Aug 19 09:16 .python-version
# -rw-r--r--  1 root root   3658 Aug 19 09:16 README.md
# drwxr-xr-x  2 root root   4096 Aug 19 09:16 resources
# -rw-r--r--  1 root root 425409 Aug 19 09:17 uv.lock
# drwxr-xr-x  5 root root   4096 Aug 19 09:18 .venv

# %%
# !mv config.yaml runs/dtg_cvpr_dk/config.yaml
# Out:
# mv: cannot move 'config.yaml' to 'runs/dtg_cvpr_dk/config.yaml': No such file or directory

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6e2160c6-8856-44cf-b109-6d890863c728" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e2160c6-8856-44cf-b109-6d890863c728">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mv best.ckpt runs/dtg_cvpr_dk/checkpoints/best.ckpt
# Out:
# mv: cannot move 'best.ckpt' to 'runs/dtg_cvpr_dk/checkpoints/best.ckpt': No such file or directory

# %%
# !find runs/dtg_cvpr_dk -type f
# Out:
# find: ‘runs/dtg_cvpr_dk’: No such file or directory

# %%
# !python main.py test --config runs/dtg_cvpr_dk/config.yaml dtg_cvpr_dk --ckpt_path runs/dtg_cvpr_dk/checkpoints/best.ckpt
# Out:
# Traceback (most recent call last):
#   File "/content/DropsToGrid/main.py", line 1, in <module>
#     from dtg.cli import cli
#   File "/content/DropsToGrid/dtg/cli.py", line 2, in <module>
#     from jsonargparse import ActionYesNo
# ModuleNotFoundError: No module named 'jsonargparse'

# %%
# !pip install jsonargparse
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.8/136.8 kB 11.9 MB/s eta 0:00:00
# ...

# %%
# !pwd
# !ls
# Out:
# /content/DropsToGrid
# best.ckpt  config.yaml	LICENSE  notebooks	 README.md  uv.lock
# configs    dtg		main.py  pyproject.toml  resources

# %%
# !python main.py test --config runs/dtg_cvpr_dk/config.yaml dtg_cvpr_dk --ckpt_path runs/dtg_cvpr_dk/checkpoints/best.ckpt
# Out:
# Traceback (most recent call last):
#   File "/content/DropsToGrid/main.py", line 1, in <module>
#     from dtg.cli import cli
#   File "/content/DropsToGrid/dtg/cli.py", line 3, in <module>
#     from lightning.pytorch import LightningModule
# ModuleNotFoundError: No module named 'lightning'

# %%
# !pip install lightning
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 43.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 21.2 MB/s eta 0:00:00
# ...

# %%
# !python main.py test --config runs/dtg_cvpr_dk/config.yaml dtg_cvpr_dk --ckpt_path runs/dtg_cvpr_dk/checkpoints/best.ckpt
# Out:
# Traceback (most recent call last):
#   File "/content/DropsToGrid/main.py", line 1, in <module>
#     from dtg.cli import cli
#   File "/content/DropsToGrid/dtg/cli.py", line 9, in <module>
#     from dtg.trainer import DtGTrainer
#   File "/content/DropsToGrid/dtg/trainer.py", line 6, in <module>
#     from dtg.callbacks.factory import create_callbacks
#   File "/content/DropsToGrid/dtg/callbacks/factory.py", line 5, in <module>
#     from dtg.callbacks.log_animations import LogAnimations
#   File "/content/DropsToGrid/dtg/callbacks/log_animations.py", line 12, in <module>
#     from dtg.logger.clearml import ClearMlLogger
#   File "/content/DropsToGrid/dtg/logger/clearml.py", line 6, in <module>
#     from clearml import Task
# ModuleNotFoundError: No module named 'clearml'

# %%
# !pip install clearml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 40.9 MB/s eta 0:00:00
# ...

# %%
# !python main.py test --config runs/dtg_cvpr_dk/config.yaml dtg_cvpr_dk --ckpt_path runs/dtg_cvpr_dk/checkpoints/best.ckpt
# Out:
# Traceback (most recent call last):
#   File "/content/DropsToGrid/main.py", line 4, in <module>
#     cli()
#   File "/content/DropsToGrid/dtg/cli.py", line 92, in cli
#     _register_classes()
#   File "/content/DropsToGrid/dtg/cli.py", line 88, in _register_classes
#     from dtg.modules.dtg.dtg import DtGModule  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/DropsToGrid/dtg/modules/dtg/__init__.py", line 1, in <module>
#     from dtg.modules.dtg.dtg import DtGModule  # noqa: F401
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/DropsToGrid/dtg/modules/dtg/dtg.py", line 21, in <module>
#     from dtg.networks.dtg.model import DtGModelConfig
#   File "/content/DropsToGrid/dtg/networks/dtg/model.py", line 9, in <module>
#     from check_shapes import check_shapes
# ModuleNotFoundError: No module named 'check_shapes'

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/DropsToGrid
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 36.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.6/766.6 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 128.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0+cu128

# %%
# !pip install check-shapes einops moviepy jsonargparse
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 4.6 MB/s eta 0:00:00
# ...

# %%
# %cd /content/DropsToGrid
# Out:
# /content/DropsToGrid

# %%
# !ls
# Out:
# best.ckpt  config.yaml	LICENSE  notebooks	 README.md  uv.lock
# configs    dtg		main.py  pyproject.toml  resources

# %%
# !find runs/dtg_cvpr_dk -type f
# Out:
# find: ‘runs/dtg_cvpr_dk’: No such file or directory
